# %% [markdown]
# # MLP Trainer

# %% [markdown]
# Trains an SKLearn MLP and saves it

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets
import sklearn.neural_network
import sklearn.model_selection
import sklearn.metrics
import seaborn as sns
import copy
import pickle

X = np.load("X.npy")
t = np.load("y.npy")

number_of_folds = 5
best_acc = 99999
best_mlp = None
kf = sklearn.model_selection.KFold(number_of_folds, shuffle=True, random_state=1)
for i, (train_index, test_index) in enumerate(kf.split(X)):
    print(f"Fold {i+1} of {number_of_folds}:")
    mlp = sklearn.neural_network.MLPClassifier(
        [100, 50, 50], 
        activation='relu',
        learning_rate='adaptive',
        random_state=1,
        solver='adam',
        early_stopping=True,
        learning_rate_init=0.0001,
        tol=0.00001,
        verbose=True
    )
    mlp.fit(X[train_index], t[train_index])
    score = mlp.score(X[test_index], t[test_index])
    print(f"The score is {score:.2%}")
    predict = mlp.predict(X[test_index])
    print("The accuracy is:")
    acc = sklearn.metrics.accuracy_score(t[test_index], predict)
    print(acc)
    conf = sklearn.metrics.confusion_matrix(t[test_index], predict)
    print("Confusion Patrix")
    print(conf)
    plt.figure()
    plt.imshow(conf, cmap="Blues", aspect='equal')
    plt.colorbar()
    plt.title(f"Confusion Matrix\nFold{i+1}")
    plt.show()
    if acc < best_acc:
        best_acc = acc
        best_mlp = copy.deepcopy(mlp)
mlp = copy.deepcopy(best_mlp)

file_name = "test_mlp.pickle"
with open(file_name, "wb") as file:
    pickle.dump(mlp, file)
# Out:
# Fold 1 of 5:
# Iteration 1, loss = inf
# Validation score: 0.607143
# Iteration 2, loss = inf
# Validation score: 0.400000
# Iteration 3, loss = 1.55133843
# Validation score: 0.392857
# Iteration 4, loss = 3.76560744
# Validation score: 0.614286
# Iteration 5, loss = 4.02891444
# Validation score: 0.614286
# Iteration 6, loss = 3.49508989
# Validation score: 0.707143
# Iteration 7, loss = 1.21449190
# Validation score: 0.750000
# Iteration 8, loss = 0.60634443
# Validation score: 0.735714
# Iteration 9, loss = 0.49042976
# Validation score: 0.757143
# Iteration 10, loss = 0.48504748
# Validation score: 0.771429
# Iteration 11, loss = 0.47408214
# Validation score: 0.764286
# Iteration 12, loss = 0.46167002
# Validation score: 0.764286
# Iteration 13, loss = 0.45980824
# Validation score: 0.764286
# Iteration 14, loss = 0.44216557
# Validation score: 0.771429
# Iteration 15, loss = 0.44906610
# Validation score: 0.778571
# Iteration 16, loss = 0.42509398
# Validation score: 0.792857
# Iteration 17, loss = 0.41807072
# Validation score: 0.771429
# Iteration 18, loss = 0.41691422
# Validation score: 0.785714
# Iteration 19, loss = 0.41212733
# Validation score: 0.671429
# Iteration 20, loss = 0.49057476
# Validation score: 0.757143
# Iteration 21, loss = 0.43472642
# Validation score: 0.792857
# Iteration 22, loss = 0.42670695
# Validation score: 0.785714
# Iteration 23, loss = 0.41082537
# Validation score: 0.792857
# Iteration 24, loss = 0.39246600
# Validation score: 0.792857
# Iteration 25, loss = 0.38257182
# Validation score: 0.778571
# Iteration 26, loss = 0.37430154
# Validation score: 0.807143
# Iteration 27, loss = 0.36105191
# Validation score: 0.807143
# Iteration 28, loss = 0.34745094
# Validation score: 0.778571
# Iteration 29, loss = 0.33537358
# Validation score: 0.821429
# Iteration 30, loss = 0.33054603
# Validation score: 0.642857
# Iteration 31, loss = 0.43891235
# Validation score: 0.814286
# Iteration 32, loss = 0.40200243
# Validation score: 0.828571
# Iteration 33, loss = 0.37322309
# Validation score: 0.807143
# Iteration 34, loss = 0.32748590
# Validation score: 0.800000
# Iteration 35, loss = 0.31375831
# Validation score: 0.828571
# Iteration 36, loss = 0.28343856
# Validation score: 0.842857
# Iteration 37, loss = 0.27571908
# Validation score: 0.850000
# Iteration 38, loss = 0.26184432
# Validation score: 0.800000
# Iteration 39, loss = 0.30276550
# Validation score: 0.728571
# Iteration 40, loss = 0.84619462
# Validation score: 0.771429
# Iteration 41, loss = 0.49373812
# Validation score: 0.764286
# Iteration 42, loss = 0.39253170
# Validation score: 0.792857
# Iteration 43, loss = 0.35910690
# Validation score: 0.771429
# Iteration 44, loss = 0.34714595
# Validation score: 0.821429
# Iteration 45, loss = 0.32895930
# Validation score: 0.800000
# Iteration 46, loss = 0.32993634
# Validation score: 0.800000
# Iteration 47, loss = 0.31742313
# Validation score: 0.800000
# Iteration 48, loss = 0.30921138
# Validation score: 0.800000
# Validation score did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# The score is 78.63%
# The accuracy is:
# 0.7863247863247863
# Confusion Patrix
# [[ 98  50]
#  [ 25 178]]
# Fold 2 of 5:
# Iteration 1, loss = inf
# Validation score: 0.404255
# Iteration 2, loss = 6.41578458
# Validation score: 0.404255
# Iteration 3, loss = 1.62503096
# Validation score: 0.737589
# Iteration 4, loss = 0.80140169
# Validation score: 0.702128
# Iteration 5, loss = 0.67286930
# Validation score: 0.702128
# Iteration 6, loss = 0.60970605
# Validation score: 0.751773
# Iteration 7, loss = 0.59002637
# Validation score: 0.730496
# Iteration 8, loss = 0.52306777
# Validation score: 0.709220
# Iteration 9, loss = 0.54856480
# Validation score: 0.737589
# Iteration 10, loss = 0.51761540
# Validation score: 0.751773
# Iteration 11, loss = 0.48614719
# Validation score: 0.751773
# Iteration 12, loss = 0.50270290
# Validation score: 0.751773
# Iteration 13, loss = 0.55015817
# Validation score: 0.716312
# Iteration 14, loss = 0.48085126
# Validation score: 0.773050
# Iteration 15, loss = 0.46272537
# Validation score: 0.758865
# Iteration 16, loss = 0.44892853
# Validation score: 0.794326
# Iteration 17, loss = 0.44806056
# Validation score: 0.758865
# Iteration 18, loss = 0.48252112
# Validation score: 0.780142
# Iteration 19, loss = 0.47521844
# Validation score: 0.645390
# Iteration 20, loss = 0.52995974
# Validation score: 0.794326
# Iteration 21, loss = 0.46908717
# Validation score: 0.815603
# Iteration 22, loss = 0.43646093
# Validation score: 0.808511
# Iteration 23, loss = 0.41620550
# Validation score: 0.829787
# Iteration 24, loss = 0.44742645
# Validation score: 0.673759
# Iteration 25, loss = 0.41099250
# Validation score: 0.851064
# Iteration 26, loss = 0.35980598
# Validation score: 0.822695
# Iteration 27, loss = 0.35164578
# Validation score: 0.851064
# Iteration 28, loss = 0.35186985
# Validation score: 0.836879
# Iteration 29, loss = 0.35374820
# Validation score: 0.794326
# Iteration 30, loss = 0.39294365
# Validation score: 0.744681
# Iteration 31, loss = 0.47821290
# Validation score: 0.773050
# Iteration 32, loss = 0.32229728
# Validation score: 0.829787
# Iteration 33, loss = 0.30516627
# Validation score: 0.822695
# Iteration 34, loss = 0.32720553
# Validation score: 0.843972
# Iteration 35, loss = 0.32975226
# Validation score: 0.843972
# Iteration 36, loss = 0.33439351
# Validation score: 0.716312
# Validation score did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# The score is 83.43%
# The accuracy is:
# 0.8342857142857143
# Confusion Patrix
# [[103  29]
#  [ 29 189]]
# Fold 3 of 5:
# Iteration 1, loss = inf
# Validation score: 0.404255
# Iteration 2, loss = inf
# Validation score: 0.404255
# Iteration 3, loss = 8.53783739
# Validation score: 0.404255
# Iteration 4, loss = 2.69917413
# Validation score: 0.595745
# Iteration 5, loss = 2.53030710
# Validation score: 0.595745
# Iteration 6, loss = 1.04141210
# Validation score: 0.418440
# Iteration 7, loss = 0.77517327
# Validation score: 0.773050
# Iteration 8, loss = 0.53699634
# Validation score: 0.801418
# Iteration 9, loss = 0.53891384
# Validation score: 0.780142
# Iteration 10, loss = 0.52530249
# Validation score: 0.751773
# Iteration 11, loss = 0.55152542
# Validation score: 0.645390
# Iteration 12, loss = 0.55248580
# Validation score: 0.758865
# Iteration 13, loss = 0.51029203
# Validation score: 0.794326
# Iteration 14, loss = 0.47732011
# Validation score: 0.787234
# Iteration 15, loss = 0.47651226
# Validation score: 0.780142
# Iteration 16, loss = 0.49945649
# Validation score: 0.773050
# Iteration 17, loss = 0.50893981
# Validation score: 0.737589
# Iteration 18, loss = 0.49592490
# Validation score: 0.773050
# Iteration 19, loss = 0.47824450
# Validation score: 0.801418
# Validation score did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# The score is 71.71%
# The accuracy is:
# 0.7171428571428572
# Confusion Patrix
# [[ 76  56]
#  [ 43 175]]
# Fold 4 of 5:
# Iteration 1, loss = inf
# Validation score: 0.595745
# Iteration 2, loss = inf
# Validation score: 0.418440
# Iteration 3, loss = inf
# Validation score: 0.460993
# Iteration 4, loss = inf
# Validation score: 0.546099
# Iteration 5, loss = 2.77617931
# Validation score: 0.595745
# Iteration 6, loss = inf
# Validation score: 0.475177
# Iteration 7, loss = 2.24504603
# Validation score: 0.737589
# Iteration 8, loss = 0.92450584
# Validation score: 0.574468
# Iteration 9, loss = 1.09765498
# Validation score: 0.723404
# Iteration 10, loss = 0.69025396
# Validation score: 0.631206
# Iteration 11, loss = 0.71891674
# Validation score: 0.680851
# Iteration 12, loss = 0.66033592
# Validation score: 0.666667
# Iteration 13, loss = 0.49550680
# Validation score: 0.758865
# Iteration 14, loss = 0.45605221
# Validation score: 0.773050
# Iteration 15, loss = 0.44056430
# Validation score: 0.780142
# Iteration 16, loss = 0.41991573
# Validation score: 0.808511
# Iteration 17, loss = 0.39569809
# Validation score: 0.808511
# Iteration 18, loss = 0.38711640
# Validation score: 0.787234
# Iteration 19, loss = 0.37685499
# Validation score: 0.822695
# Iteration 20, loss = 0.39566950
# Validation score: 0.829787
# Iteration 21, loss = 0.39376024
# Validation score: 0.716312
# Iteration 22, loss = 0.48391687
# Validation score: 0.794326
# Iteration 23, loss = 0.45748612
# Validation score: 0.794326
# Iteration 24, loss = 0.38139696
# Validation score: 0.673759
# Iteration 25, loss = 0.35785025
# Validation score: 0.808511
# Iteration 26, loss = 0.33554517
# Validation score: 0.829787
# Iteration 27, loss = 0.32145005
# Validation score: 0.822695
# Iteration 28, loss = 0.31347267
# Validation score: 0.829787
# Iteration 29, loss = 0.33311108
# Validation score: 0.815603
# Iteration 30, loss = 0.32495779
# Validation score: 0.765957
# Iteration 31, loss = 0.39062915
# Validation score: 0.815603
# Validation score did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# The score is 79.43%
# The accuracy is:
# 0.7942857142857143
# Confusion Patrix
# [[102  34]
#  [ 38 176]]
# Fold 5 of 5:
# Iteration 1, loss = inf
# Validation score: 0.609929
# Iteration 2, loss = inf
# Validation score: 0.609929
# Iteration 3, loss = inf
# Validation score: 0.609929
# Iteration 4, loss = 3.24192018
# Validation score: 0.390071
# Iteration 5, loss = 1.70940372
# Validation score: 0.624113
# Iteration 6, loss = 1.60956102
# Validation score: 0.453901
# Iteration 7, loss = 0.88026929
# Validation score: 0.758865
# Iteration 8, loss = 0.61898717
# Validation score: 0.794326
# Iteration 9, loss = 0.51427390
# Validation score: 0.773050
# Iteration 10, loss = 0.50330380
# Validation score: 0.794326
# Iteration 11, loss = 0.53521999
# Validation score: 0.751773
# Iteration 12, loss = 0.48568778
# Validation score: 0.787234
# Iteration 13, loss = 0.48747440
# Validation score: 0.801418
# Iteration 14, loss = 0.47851068
# Validation score: 0.801418
# Iteration 15, loss = 0.47710919
# Validation score: 0.673759
# Iteration 16, loss = 0.54106890
# Validation score: 0.666667
# Iteration 17, loss = 0.54078102
# Validation score: 0.744681
# Iteration 18, loss = 0.45815641
# Validation score: 0.794326
# Iteration 19, loss = 0.45279964
# Validation score: 0.787234
# Iteration 20, loss = 0.45830804
# Validation score: 0.815603
# Iteration 21, loss = 0.43814536
# Validation score: 0.787234
# Iteration 22, loss = 0.42536821
# Validation score: 0.829787
# Iteration 23, loss = 0.41290161
# Validation score: 0.794326
# Iteration 24, loss = 0.40835635
# Validation score: 0.822695
# Iteration 25, loss = 0.39749447
# Validation score: 0.815603
# Iteration 26, loss = 0.40876030
# Validation score: 0.780142
# Iteration 27, loss = 0.39307625
# Validation score: 0.808511
# Iteration 28, loss = 0.39303366
# Validation score: 0.751773
# Iteration 29, loss = 0.43248734
# Validation score: 0.773050
# Iteration 30, loss = 0.40132570
# Validation score: 0.780142
# Iteration 31, loss = 0.36087671
# Validation score: 0.822695
# Iteration 32, loss = 0.33335425
# Validation score: 0.822695
# Iteration 33, loss = 0.32430142
# Validation score: 0.801418
# Validation score did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# The score is 80.00%
# The accuracy is:
# 0.8
# Confusion Patrix
# [[119  31]
#  [ 39 161]]
