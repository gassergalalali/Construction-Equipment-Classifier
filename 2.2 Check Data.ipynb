# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.load("X.npy")
t = np.load("y.npy")

# %%
number = np.random.randint(0, len(X))
print(f"Image number {number}: Has Equipment? {t[number]}")
plt.imshow(X[number].reshape((100, 100)), cmap="Greys")
plt.show()
# Out:
# Image number 185: Has Equipment? 1
